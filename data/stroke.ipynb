# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

data = pandas.read_csv('./data.csv')

# %%
data.astype({'Frame': int, 'Value': int})
#data = data[data['Frame'] > 1000]
data = data[data['Frame'] < 4000]
data = data[data['Value'] < 1000]

# %%
data.plot(x='Frame', y='Value')
